# %% [markdown]
# <a href="https://colab.research.google.com/github/SLTH-Project/ThaiSignLanguage/blob/main/Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from numpy import expand_dims
import numpy as np
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.mobilenet import preprocess_input

import tensorflow as tf

from PIL import Image 
from PIL import ImageFilter 
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from scipy import ndimage
#from scipy.misc import imread

import os
import cv2

# %% [markdown]
# # Resize

# %%
root_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset_Original/9/"
save_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/99/" 
def Resize (root_dir,save_dir):
    for indexImage in os.listdir(root_dir):  
        subImage= os.path.join(root_dir, indexImage) 
        img = Image.open(subImage) 
        saveResize = os.path.join(save_dir, 'Resize_'+indexImage) 
        img.resize((128, 128)).save(saveResize)

if __name__ == '__main__': 
  Resize(root_dir,save_dir)

# %% [markdown]
# #Make colors - Add light

# %%
root_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/9/" 
Ext ='.jpg'
def add_light(image, gamma, count):
    inverseGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** inverseGamma) *
                      255 for i in np.arange(0, 256)]).astype("uint8")
    image = cv2.LUT(image, table)
    if gamma >= 1:
        cv2.imwrite(root_dir + "Make_" + "light_" +
                    str(gamma) + str(count) + Ext, image)
    else:
        cv2.imwrite(root_dir + "Make_" + "dark_" +
                    str(gamma) + str(count) + Ext, image)

if __name__ == '__main__': 
  
  imfilelist = [os.path.join(root_dir, f)
                for f in os.listdir(root_dir) if f.endswith(Ext)]
  for i, el in enumerate(imfilelist):
    image = Image.open(el)
    image = np.array(image)
    add_light(image, 1.5, i)
    add_light(image, 2.5, i)
    #add_light(image, 3.0, i)
    add_light(image, 0.7, i)

# %% [markdown]
# #Augmentation - ImageDataGenerator Keras

# %%
root_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/99/" 
save_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/9/" 
def Tensor_img_gen (root_dir,save_dir ):
  for indexImage in os.listdir(root_dir): 
      load_image = image.load_img(os.path.join(root_dir, indexImage), color_mode ='rgb',target_size = (128,128))
      load_image = image.img_to_array(load_image)
      load_image = np.expand_dims(load_image, axis = 0)
      load_image = preprocess_input(load_image)
      aug = ImageDataGenerator(
              featurewise_center=True,
              samplewise_center=True,
              featurewise_std_normalization=True,
              samplewise_std_normalization=True,
              rotation_range=15,
              width_shift_range=0.1,
              height_shift_range=0.1,
              brightness_range=[0.8,1.1],
              shear_range=0.2,
              zoom_range=0.1,
              fill_mode="nearest",
              horizontal_flip=True,
              )
      for x, val in zip(aug.flow(load_image,                    
          save_to_dir=save_dir,    
          save_prefix='aug_',      
          save_format='jpg'),range(10)) : 
          pass    # here we define a range because we want 10 augmented images otherwise it will keep looping forever I think
      
if __name__ == '__main__': 
  Tensor_img_gen(root_dir,save_dir)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %% [markdown]
# #Display

# %%
from PIL import ImageFilter 
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt

# %%
display_dir = "/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/1/" 
plt.figure(1, figsize=(40,100))
images=[]
n_columns = 6
for i in range(112):
    plt.subplot(19, n_columns, i+1)
    plt.title('img ' + str(i))
    for imagePath in os.listdir(display_dir):  
      inputPath = os.path.join(display_dir, imagePath) 
      img= Image.open(inputPath) 
      img=np.array(img)     
      #img=img.flatten()   
      images.append(img)     
    plt.imshow(np.reshape(images[i],[128,128,3]))
    #print(test_label[i])

# %% [markdown]
# #Count

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/0/'))
# Out:
# 1716

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/1/'))
# Out:
# 1716

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/2/'))
# Out:
# 1717

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/3/'))
# Out:
# 1713

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/4/'))
# Out:
# 1726

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/5/'))
# Out:
# 1719

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/6/'))
# Out:
# 1695

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/7/'))
# Out:
# 1729

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/8/'))
# Out:
# 1711

# %%
len(os.listdir('/content/drive/MyDrive/All Dataset/Dataset/Github/ThaiSignLanguage/Dataset/Dataset0-9_Test/Dataset0-9_Aug/9/'))
# Out:
# 1727
